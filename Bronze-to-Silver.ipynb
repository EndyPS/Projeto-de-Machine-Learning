# %%
# importações de libs
from pyspark.sql.types import *
from pyspark.sql.functions import *
from pandas import * 
from datetime import datetime
from notebookutils import mssparkutils

# Detalhes do contexto da sessão
#context_info = mssparkutils.runtime.context

# configurações para compatibilidade de formatos de campos importados da fonte
spark.conf.set("spark.sql.session.timeZone", "America/Sao_Paulo")
spark.conf.set("spark.sql.legacy.parquet.int96RebaseModeInRead", "CORRECTED")
spark.conf.set("spark.sql.legacy.parquet.int96RebaseModeInWrite", "CORRECTED")
spark.conf.set("spark.sql.legacy.parquet.datetimeRebaseModeInRead", "CORRECTED")
spark.conf.set("spark.sql.legacy.parquet.datetimeRebaseModeInWrite", "CORRECTED")
# Out:
# StatementMeta(, e4942a31-f548-429a-9552-2cbf6c312c41, 3, Finished, Available, Finished)

# %%
root_bronze='abfss://Estadual@onelake.dfs.fabric.microsoft.com/bronze.Lakehouse/Tables'
root_silver='abfss://Estadual@onelake.dfs.fabric.microsoft.com/silver.Lakehouse/Tables'
# Out:
# StatementMeta(, e4942a31-f548-429a-9552-2cbf6c312c41, 4, Finished, Available, Finished)

# %%
df_caged=spark.read.format("delta").load(f"{root_bronze}/novo_caged")

df_caged.write.format("delta").mode("overwrite")\
    .option("overwriteSchema","true")\
    .option("path",f"{root_silver}/novo_caged")\
    .saveAsTable("novo_caged")
# Out:
# StatementMeta(, e4942a31-f548-429a-9552-2cbf6c312c41, 5, Finished, Available, Finished)
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[14], line 6
#       1 df_caged=spark.read.format("delta").load(f"{root_bronze}/novo_caged")
#       3 df_caged.write.format("delta").mode("overwrite")\
#       4     .option("overwriteSchema","true")\
#       5     .option("path",f"{root_silver}/novo_caged")\
# ----> 6     .saveAsTable("novo_caged")
#
# File /opt/spark/python/lib/pyspark.zip/pyspark/sql/readwriter.py:1521, in DataFrameWriter.saveAsTable(self, name, format, mode, partitionBy, **options)
#    1519 if format is not None:
#    1520     self.format(format)
# -> 1521 self._jwrite.saveAsTable(name)
#
# File ~/cluster-env/trident_env/lib/python3.10/site-packages/py4j/java_gateway.py:1322, in JavaMember.__call__(self, *args)
#    1316 command = proto.CALL_COMMAND_NAME +\
# ...
